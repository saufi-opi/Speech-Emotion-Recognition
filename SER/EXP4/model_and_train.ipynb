# %% [markdown]
# # **Conv1D - MFCC**

# %%
#importing libraries

import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, LSTM

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Data preparation

Features=pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/FYP-SER/SER4/features_without_silent_2nd_version.csv")
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3240, 50), (3240, 8), (1080, 50), (1080, 8))

# %%
#scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3240, 50), (3240, 8), (1080, 50), (1080, 8))

# %%
# import joblib

# # Save the scaler to a file
# joblib.dump(scaler, '/content/gdrive/MyDrive/Colab Notebooks/FYP-SER/SER4/scaler.pkl')

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3240, 50, 1), (3240, 8), (1080, 50, 1), (1080, 8))

# %%
#Modelling

model=Sequential()
model.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='tanh', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='tanh'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='tanh'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='tanh'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='tanh'))
model.add(Dropout(0.3))

model.add(Dense(units=8, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 50, 512)           3072
#
#  max_pooling1d (MaxPooling1D  (None, 25, 512)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 25, 256)           655616
#
#  max_pooling1d_1 (MaxPooling  (None, 13, 256)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 13, 256)           327936
#
#  max_pooling1d_2 (MaxPooling  (None, 7, 256)           0
#  1D)
#
#  dropout (Dropout)           (None, 7, 256)            0
#
#  conv1d_3 (Conv1D)           (None, 7, 128)            163968
#
#  max_pooling1d_3 (MaxPooling  (None, 4, 128)           0
#  1D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 32)                16416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 1,167,272
# Trainable params: 1,167,272
# Non-trainable params: 0
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
n_epochs=100
history=model.fit(x_train, y_train, batch_size=64, epochs=n_epochs, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/100
# 51/51 [==============================] - 9s 23ms/step - loss: 2.0302 - accuracy: 0.2194 - val_loss: 1.8728 - val_accuracy: 0.3046 - lr: 0.0010
# Epoch 2/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.8167 - accuracy: 0.3071 - val_loss: 1.6767 - val_accuracy: 0.3750 - lr: 0.0010
# Epoch 3/100
# 51/51 [==============================] - 0s 8ms/step - loss: 1.6041 - accuracy: 0.3935 - val_loss: 1.5320 - val_accuracy: 0.4241 - lr: 0.0010
# Epoch 4/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.4259 - accuracy: 0.4710 - val_loss: 1.3560 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 5/100
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2648 - accuracy: 0.5392 - val_loss: 1.2842 - val_accuracy: 0.5241 - lr: 0.0010
# Epoch 6/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.1537 - accuracy: 0.5858 - val_loss: 1.1833 - val_accuracy: 0.5741 - lr: 0.0010
# Epoch 7/100
# 51/51 [==============================] - 0s 9ms/step - loss: 1.0443 - accuracy: 0.6358 - val_loss: 1.1642 - val_accuracy: 0.5796 - lr: 0.0010
# Epoch 8/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.9506 - accuracy: 0.6762 - val_loss: 0.9812 - val_accuracy: 0.6537 - lr: 0.0010
# Epoch 9/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.7823 - accuracy: 0.7386 - val_loss: 0.9562 - val_accuracy: 0.6750 - lr: 0.0010
# Epoch 10/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.7170 - accuracy: 0.7562 - val_loss: 0.9247 - val_accuracy: 0.6843 - lr: 0.0010
# Epoch 11/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.5804 - accuracy: 0.8127 - val_loss: 0.9362 - val_accuracy: 0.6769 - lr: 0.0010
# Epoch 12/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.5302 - accuracy: 0.8324 - val_loss: 0.8244 - val_accuracy: 0.7046 - lr: 0.0010
# Epoch 13/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.4344 - accuracy: 0.8682 - val_loss: 0.9592 - val_accuracy: 0.6852 - lr: 0.0010
# Epoch 14/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.3967 - accuracy: 0.8735 - val_loss: 0.8253 - val_accuracy: 0.7204 - lr: 0.0010
# Epoch 15/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3069 - accuracy: 0.9074 - val_loss: 0.8550 - val_accuracy: 0.7046 - lr: 0.0010
# Epoch 16/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.2607 - accuracy: 0.9299 - val_loss: 0.7302 - val_accuracy: 0.7546 - lr: 0.0010
# Epoch 17/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.2167 - accuracy: 0.9423 - val_loss: 0.6515 - val_accuracy: 0.7685 - lr: 0.0010
# Epoch 18/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1686 - accuracy: 0.9562 - val_loss: 0.6925 - val_accuracy: 0.7713 - lr: 0.0010
# Epoch 19/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1349 - accuracy: 0.9670 - val_loss: 0.6846 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 20/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1277 - accuracy: 0.9725 - val_loss: 0.6690 - val_accuracy: 0.7833 - lr: 0.0010
# Epoch 21/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1102 - accuracy: 0.9719 - val_loss: 0.6244 - val_accuracy: 0.7944 - lr: 0.0010
# Epoch 22/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1019 - accuracy: 0.9725 - val_loss: 0.7874 - val_accuracy: 0.7546 - lr: 0.0010
# Epoch 23/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0929 - accuracy: 0.9765 - val_loss: 0.6865 - val_accuracy: 0.7870 - lr: 0.0010
# Epoch 24/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0623 - accuracy: 0.9889 - val_loss: 0.6619 - val_accuracy: 0.8028 - lr: 0.0010
# Epoch 25/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0625 - accuracy: 0.9883 - val_loss: 0.6479 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 26/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0953 - accuracy: 0.9725 - val_loss: 0.9765 - val_accuracy: 0.7194 - lr: 0.0010
# Epoch 27/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0694 - accuracy: 0.9833 - val_loss: 0.5605 - val_accuracy: 0.8194 - lr: 4.0000e-04
# Epoch 28/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0256 - accuracy: 0.9981 - val_loss: 0.5360 - val_accuracy: 0.8296 - lr: 4.0000e-04
# Epoch 29/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0204 - accuracy: 0.9985 - val_loss: 0.5379 - val_accuracy: 0.8259 - lr: 4.0000e-04
# Epoch 30/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0176 - accuracy: 0.9997 - val_loss: 0.5279 - val_accuracy: 0.8333 - lr: 4.0000e-04
# Epoch 31/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.5140 - val_accuracy: 0.8343 - lr: 4.0000e-04
# Epoch 32/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0143 - accuracy: 0.9994 - val_loss: 0.5403 - val_accuracy: 0.8398 - lr: 4.0000e-04
# Epoch 33/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0131 - accuracy: 0.9994 - val_loss: 0.5327 - val_accuracy: 0.8361 - lr: 4.0000e-04
# Epoch 34/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.5295 - val_accuracy: 0.8398 - lr: 4.0000e-04
# Epoch 35/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.5258 - val_accuracy: 0.8407 - lr: 4.0000e-04
# Epoch 36/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0126 - accuracy: 0.9994 - val_loss: 0.5399 - val_accuracy: 0.8361 - lr: 4.0000e-04
# Epoch 37/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 0.9997 - val_loss: 0.5350 - val_accuracy: 0.8324 - lr: 4.0000e-04
# Epoch 38/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.5267 - val_accuracy: 0.8407 - lr: 4.0000e-04
# Epoch 39/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.5368 - val_accuracy: 0.8380 - lr: 4.0000e-04
# Epoch 40/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0092 - accuracy: 0.9997 - val_loss: 0.5395 - val_accuracy: 0.8398 - lr: 4.0000e-04
# Epoch 41/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.5378 - val_accuracy: 0.8417 - lr: 4.0000e-04
# Epoch 42/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.5380 - val_accuracy: 0.8380 - lr: 4.0000e-04
# Epoch 43/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5375 - val_accuracy: 0.8426 - lr: 4.0000e-04
# Epoch 44/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.5380 - val_accuracy: 0.8352 - lr: 4.0000e-04
# Epoch 45/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5500 - val_accuracy: 0.8398 - lr: 4.0000e-04
# Epoch 46/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5437 - val_accuracy: 0.8380 - lr: 4.0000e-04
# Epoch 47/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5524 - val_accuracy: 0.8398 - lr: 4.0000e-04
# Epoch 48/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5458 - val_accuracy: 0.8370 - lr: 4.0000e-04
# Epoch 49/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.8407 - lr: 1.6000e-04
# Epoch 50/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5417 - val_accuracy: 0.8370 - lr: 1.6000e-04
# Epoch 51/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5409 - val_accuracy: 0.8380 - lr: 1.6000e-04
# Epoch 52/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5471 - val_accuracy: 0.8389 - lr: 6.4000e-05
# Epoch 53/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.5453 - val_accuracy: 0.8398 - lr: 6.4000e-05
# Epoch 54/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5462 - val_accuracy: 0.8398 - lr: 6.4000e-05
# Epoch 55/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5464 - val_accuracy: 0.8380 - lr: 6.4000e-05
# Epoch 56/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5435 - val_accuracy: 0.8389 - lr: 6.4000e-05
# Epoch 57/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5426 - val_accuracy: 0.8398 - lr: 6.4000e-05
# Epoch 58/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5422 - val_accuracy: 0.8389 - lr: 2.5600e-05
# Epoch 59/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5437 - val_accuracy: 0.8389 - lr: 2.5600e-05
# Epoch 60/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5429 - val_accuracy: 0.8398 - lr: 1.0240e-05
# Epoch 61/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5429 - val_accuracy: 0.8398 - lr: 1.0240e-05
# Epoch 62/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5431 - val_accuracy: 0.8398 - lr: 4.0960e-06
# Epoch 63/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.8398 - lr: 4.0960e-06
# Epoch 64/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.6384e-06
# Epoch 65/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.6384e-06
# Epoch 66/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 6.5536e-07
# Epoch 67/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 6.5536e-07
# Epoch 68/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5432 - val_accuracy: 0.8398 - lr: 2.6214e-07
# Epoch 69/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5432 - val_accuracy: 0.8398 - lr: 2.6214e-07
# Epoch 70/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5432 - val_accuracy: 0.8398 - lr: 1.0486e-07
# Epoch 71/100
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0486e-07
# Epoch 72/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 73/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 74/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 75/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 76/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 77/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 78/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 79/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 80/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 81/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 82/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 83/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 84/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 85/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 86/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 87/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 88/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 89/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 90/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 91/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 92/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 93/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 94/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 95/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 96/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 97/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 98/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 99/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.8398 - lr: 1.0000e-07
# Epoch 100/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.8398 - lr: 1.0000e-07

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(n_epochs)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 34/34 [==============================] - 0s 6ms/step - loss: 0.5434 - accuracy: 0.8398
# Accuracy of our model on test data :  83.9814841747284 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 34/34 [==============================] - 0s 3ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(100)
# Out:
#    Predicted Labels Actual Labels
# 0              calm          calm
# 1           disgust       disgust
# 2          surprise      surprise
# 3              calm          calm
# 4           disgust       disgust
# ..              ...           ...
# 95            angry         angry
# 96          neutral       neutral
# 97          disgust       disgust
# 98          disgust       disgust
# 99         surprise         happy
#
# [100 rows x 2 columns]

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Greens', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.92      0.87      0.90       158
#         calm       0.81      0.86      0.83       123
#      disgust       0.79      0.85      0.82       150
#         fear       0.86      0.83      0.85       138
#        happy       0.82      0.84      0.83       149
#      neutral       0.84      0.69      0.76        86
#          sad       0.83      0.84      0.83       141
#     surprise       0.84      0.87      0.86       135
#
#     accuracy                           0.84      1080
#    macro avg       0.84      0.83      0.83      1080
# weighted avg       0.84      0.84      0.84      1080

# %%
# model.save('/content/gdrive/MyDrive/Colab Notebooks/FYP-SER/SER4/model_2nd_version.h5')
